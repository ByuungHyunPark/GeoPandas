# %%
import pandas as pd
import geopandas as gpd
gpd.__version__

#matplotlib 한글 시각화 위한 코드
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
link_data = gpd.read_file('C:/Users/병현/Desktop/인턴십_프로젝트/Link_CAR_Mobility_Analyzer/Link_Level6 Map_2018_UTMK.shp', encoding='utf-8')

# %%
link_data.head()
# Out:
#      link_id up_f_node up_t_node dw_f_node dw_t_node max_speed road_name  \
# 0  338700014    692901    692903    692903    692901         0    자은서부2길
# 1  338700016    693771    692903    692903    693771         0    자은서부2길
# 2  338700018    692904    692906    692906    692904         0    자은서부2길
# 3  338700019    693771    692906    692906    693771         0    자은서부2길
# 4  412300044    100923    100185    100185    100923        50  대한로140번길
#
#   road_no road_rank link_type  ... RC_ID RC_Name RC_hist RC_date RC_length  \
# 0       0       107     32768  ...  None    None     410    None      None
# 1       0       107     32768  ...  None    None     410    None      None
# 2       0       107     32768  ...  None    None     410    None      None
# 3       0       107     32768  ...  None    None     410    None      None
# 4       0       107     32768  ...  None    None       0    None      None
#
#   old_link_i source   rc_desc rc_apply  \
# ...

# %%
plt.rcParams['figure.figsize']=(10,20)

link_data.plot()
plt.show()

# %%
cheonju_link_data = link_data[link_data['sigungu_id'].str[:4] == '3304']

# %%
plt.rcParams['figure.figsize']=(10,20)

cheonju_link_data.plot()
cj_rotery_link.plot(color = 'red')
plt.show()

# %%
cheonju_link_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-87dc37797c6f> in <module>
# ----> 1 cheonju_link_data
#
# NameError: name 'cheonju_link_data' is not defined

# %%
cj_rotery_link = cheonju_link_data[cheonju_link_data['link_type'] == '64']
cj_roundabout_link = cheonju_link_data[cheonju_link_data['link_type'] == '128']

# %%
cheonju_link_data['link_type'].value_counts()
# Out:
# 32768    7374
# 4        1822
# 34816     703
# 1         360
# 8         272
# 32         95
# 64         67
# 2          53
# 2052       47
# 16         24
# 36864       2
# Name: link_type, dtype: int64

# %%
cheonju_link_data = cheonju_link_data.reset_index()
cheonju_link_data.drop('index', inplace = True, axis= 1)
cheonju_link_data
# Out:
#          link_id up_f_node up_t_node dw_f_node dw_t_node max_speed road_name  \
# 0      563301129    303293    303461    303461    303293        30    궁현연꽃2길
# 1      563301193    303206    303298    303298    303206        60     저산태성로
# 2      563301201    303293    303325    303325    303293        60     저산궁현길
# 3      563302088    303294    303324    303324    303294        60       서부로
# 4      563302414    304096    303453    303453    304096        60       서부로
# ...          ...       ...       ...       ...       ...       ...       ...
# 10814  567400355    321707    321708    321708    321707        40     운암계원로
# 10815  900000055    900036    309278    309278    900036        40      None
# 10816  900000070    308447    900036    900036    308447        40      None
# 10817  900000072    900037    560797    560797    900037         0      None
# 10818  900000117    900037    316177    316177    900037         0      None
#
# ...

# %%
cheonju_link_data.to_csv('청주시Link.csv')

# %%
cj_roundabout_link
# Out:
# Empty GeoDataFrame
# Columns: [link_id, up_f_node, up_t_node, dw_f_node, dw_t_node, max_speed, road_name, road_no, road_rank, link_type, pavement, road_type, facil_name, tg_name, up_lanes, dw_lanes, lanes, oneway, length, width, Level, spot_id, hov_lane, shov_lane, car_lane, num_cross, barrier, up_its_id, dw_its_id, sido_id, sigungu_id, emd_id, up_vdf, dw_vdf, up_i_speed, dw_i_speed, up_capa, dw_capa, emme_check, up_c_year, dw_c_year, end_year, m_check, m_date, up_v_Link, dw_v_Link, RC_ID, RC_Name, RC_hist, RC_date, RC_length, old_link_i, source, rc_desc, rc_apply, geometry]
# Index: []
#
# [0 rows x 56 columns]

# %%
cj_rotery_link['num_cross'].value_counts()
# Out:
# 0    67
# Name: num_cross, dtype: int64

# %%
cj_roundabout_link['num_cross'].value_counts()
# Out:
# Series([], Name: num_cross, dtype: int64)

# %%
cheonju_link_data['width'].value_counts()
# Out:
# 2    5003
# 3    2612
# 1    2093
# 4    1111
# Name: width, dtype: int64

# %%
cheonju_link_data['length'].describe()
# Out:
# count    10819.000000
# mean         0.165631
# std          0.332847
# min          0.004000
# 25%          0.036000
# 50%          0.074000
# 75%          0.170000
# max          7.176000
# Name: length, dtype: float64

# %%
cheonju_link_data['length'] = cheonju_link_data['length'].astype(float)
# Out:
# C:\Anaconda3_19_1222\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
cheonju_link_data['length'].hist()
